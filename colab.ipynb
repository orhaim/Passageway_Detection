# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
root_path="/content/drive/My Drive/Passageway_Detection_Lab/Passageway_detection-master"
if not os.path.exists(root_path):
    os.makedirs(root_path)
os.environ["ROOT_PATH"] = root_path


# check env variable
# !echo "$ROOT_PATH"
# !ls -la "$ROOT_PATH"

# %%
# %%shell
# # install dependency
# pip install cython
# pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
# %%shell
#
# #### change manually Runtime type to GPU! ####
# ##############################################
#
# cd "$ROOT_PATH"
# echo "-----------"
# echo "my path is:"
# realpath .
# ls -l
# echo "-----------"
#
#
# # clone eyals project
# git clone https://github.com/orhaim/Passageway_Detection.git
#
# # enter the project folder
# cd Passageway_Detection
# git pull # update to latest version
# realpath . # print full current path
# ls -l . # show list of files in current path
#
#
# # start train
# python trainer.py --num_epochs 100

# %%
# %%shell
#
# cd "$ROOT_PATH"
# cd Passageway_Detection
#
# # create new annotation file (using the trained weight)
# python runMe.py
#
#
# ### maybe wont work on colab
# # test the results (based on the annotation file runMe.py create)
# python project_test.py
